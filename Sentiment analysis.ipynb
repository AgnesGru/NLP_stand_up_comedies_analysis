# %% [markdown]
# ### Polarity: How positive or negative a word is. -1 is very negative. +1 is very positive.
# ### Subjectivity: How subjective, or opinionated a word is. 0 is fact. +1 is very much an opinion.

# %%
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                 transcript         full_name
# louis    Intro\nFade the music out. Let’s roll. Hold th...          Ali Wong
# dave     This is Dave. He tells dirty jokes for a livin...  Anthony Jeselnik
# ricky    Hello. Hello! How you doing? Great. Thank you....         Bill Burr
# bo       Bo What? Old MacDonald had a farm E I E I O An...        Bo Burnham
# bill     [cheers and applause] All right, thank you! Th...    Dave Chappelle
# jim      [Car horn honks] [Audience cheering] [Announce...      Hasan Minhaj
# john     Armed with boyish charm and a sharp wit, the f...     Jim Jefferies
# hasan    [theme music: orchestral hip-hop] [crowd roars...         Joe Rogan
# ali      Ladies and gentlemen, please welcome to the st...      John Mulaney
# anthony  Thank you. Thank you. Thank you, San Francisco...        Louis C.K.
# mike     Wow. Hey, thank you. Thanks. Thank you, guys. ...    Mike Birbiglia
# joe      [rock music playing] [audience cheering] [anno...     Ricky Gervais

# %%
from textblob import TextBlob  # library on top of nltk

# %%
polarity = lambda x: TextBlob(x).sentiment.polarity
subjectivity = lambda x: TextBlob(x).sentiment.subjectivity

data['polarity'] = data['transcript'].apply(polarity)
data['subjectivity'] = data['transcript'].apply(subjectivity)
data.sort_values(by='subjectivity')
# Out:
#                                                 transcript         full_name  \
# hasan    [theme music: orchestral hip-hop] [crowd roars...         Joe Rogan
# ali      Ladies and gentlemen, please welcome to the st...      John Mulaney
# john     Armed with boyish charm and a sharp wit, the f...     Jim Jefferies
# ricky    Hello. Hello! How you doing? Great. Thank you....         Bill Burr
# dave     This is Dave. He tells dirty jokes for a livin...  Anthony Jeselnik
# louis    Intro\nFade the music out. Let’s roll. Hold th...          Ali Wong
# mike     Wow. Hey, thank you. Thanks. Thank you, guys. ...    Mike Birbiglia
# jim      [Car horn honks] [Audience cheering] [Announce...      Hasan Minhaj
# bill     [cheers and applause] All right, thank you! Th...    Dave Chappelle
# bo       Bo What? Old MacDonald had a farm E I E I O An...        Bo Burnham
# joe      [rock music playing] [audience cheering] [anno...     Ricky Gervais
# anthony  Thank you. Thank you. Thank you, San Francisco...        Louis C.K.
#
#          polarity  subjectivity
# hasan    0.088947      0.460618
# ali      0.072204      0.481920
# john     0.084262      0.482675
# ricky    0.068312      0.496803
# dave    -0.000420      0.512993
# louis    0.059578      0.514657
# mike     0.094753      0.517327
# jim      0.046566      0.522425
# bill     0.017819      0.536699
# bo       0.077133      0.537696
# joe      0.007771      0.550306
# anthony  0.057654      0.557406
